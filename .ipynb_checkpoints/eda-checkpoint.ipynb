# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import linear_model
import matplotlib.ticker as ticker

# %%
df = pd.read_json('data.json')
df.head(5)
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.582   0.525    1    -7.163     0       0.0627       0.11100
# 1         0.514   0.730    1    -5.934     1       0.0598       0.00146
# 2         0.461   0.593    1    -4.954     1       0.0356       0.17000
# 3         0.680   0.826    0    -5.487     1       0.0309       0.02120
# 4         0.735   0.795   11    -6.523     0       0.1130       0.02960
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.000000    0.1340    0.510  133.249  audio_features
# 1          0.000095    0.0897    0.334  171.005  audio_features
# 2          0.000000    0.3070    0.175  134.170  audio_features
# 3          0.000012    0.5430    0.644  118.051  audio_features
# 4          0.000032    0.0678    0.905  122.000  audio_features
#
#                        id                                   uri  \
# 0  2Ch7LmS7r2Gy2kc64wv3Bz  spotify:track:2Ch7LmS7r2Gy2kc64wv3Bz
# 1  0VjIjW4GlUZAMYd2vXMi3b  spotify:track:0VjIjW4GlUZAMYd2vXMi3b
# 2  09mEdoA6zrmBPgTEN5qXmN  spotify:track:09mEdoA6zrmBPgTEN5qXmN
# 3  5QO79kh1waicV47BqGRL3g  spotify:track:5QO79kh1waicV47BqGRL3g
# 4  1nH2PkJL1XoUq8oE6tBZoU  spotify:track:1nH2PkJL1XoUq8oE6tBZoU
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/2Ch7LmS7r2Gy...
# 1  https://api.spotify.com/v1/tracks/0VjIjW4GlUZA...
# 2  https://api.spotify.com/v1/tracks/09mEdoA6zrmB...
# 3  https://api.spotify.com/v1/tracks/5QO79kh1waic...
# 4  https://api.spotify.com/v1/tracks/1nH2PkJL1XoU...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/2Ch7...       260253
# 1  https://api.spotify.com/v1/audio-analysis/0VjI...       200040
# 2  https://api.spotify.com/v1/audio-analysis/09mE...       228373
# 3  https://api.spotify.com/v1/audio-analysis/5QO7...       215627
# 4  https://api.spotify.com/v1/audio-analysis/1nH2...       188918
#
#    time_signature
# 0               4
# 1               4
# 2               3
# 3               4
# 4               4

# %%
drop_columns = ['type', 'id', 'uri', 'track_href', 'analysis_url']

# %%
df1 = df.copy()
df1.drop(drop_columns, axis = 1, inplace = True)
df1
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.582   0.525    1    -7.163     0       0.0627       0.11100
# 1          0.514   0.730    1    -5.934     1       0.0598       0.00146
# 2          0.461   0.593    1    -4.954     1       0.0356       0.17000
# 3          0.680   0.826    0    -5.487     1       0.0309       0.02120
# 4          0.735   0.795   11    -6.523     0       0.1130       0.02960
# 5          0.585   0.564    0    -7.063     0       0.0515       0.06710
# 6          0.687   0.781    1    -4.806     1       0.0530       0.03610
# 7          0.705   0.769    9    -5.526     0       0.0425       0.11300
# 8          0.638   0.474    5   -12.700     0       0.1240       0.35100
# 9          0.553   0.659    8    -7.295     1       0.0391       0.00270
# 10         0.773   0.819    0    -5.946     0       0.1180       0.42800
# 11         0.679   0.587    7    -7.015     1       0.2760       0.14100
# 12         0.650   0.760    0    -4.422     0       0.0446       0.25500
# 13         0.736   0.848    9    -5.494     0       0.1710       0.10300
# 14         0.747   0.739    8    -6.008     1       0.0487       0.01060
# 13          0.000000    0.2990   0.7840  109.946       263642               4
# 14          0.000022    0.1010   0.5230  120.996       220196               4
# 15          0.000000    0.0972   0.4260  119.844       252227               3
# 16          0.009430    0.3010   0.3190   89.019       405213               4
# 17          0.000081    0.0736   0.7170  100.021       237520               4
# 18          0.000024    0.1120   0.1960  100.626       211421               4
# 19          0.002330    0.0845   0.4360  128.986       186173               4
# 20          0.000001    0.1560   0.2520  170.062       198267               4
# 21          0.000000    0.1350   0.0713  134.078       249040               4
# 22          0.000000    0.0764   0.2400   98.992       236133               4
# 23          0.000000    0.0844   0.2540  101.102       348853               4
# 24          0.000005    0.3250   0.3260  114.078       323747               4
# 25          0.000000    0.1040   0.1860  120.073       312427               4
# 26          0.006040    0.1210   0.1430  108.959       361027               4
# 27          0.001320    0.2470   0.6790  178.043       210795               4
# 28          0.000006    0.1420   0.6090  179.984       200482               4
# 29          0.043700    0.2340   0.0397  131.922       222307               4
# 30          0.000132    0.1110   0.3210  151.980       144540               4
# 31          0.000093    0.3270   0.3180  100.901       185689               3
# 32          0.000573    0.1290   0.1070   92.026       221107               4
# 33          0.000014    0.1110   0.2900  122.585       220293               4
# 34          0.000162    0.1630   0.1550  113.260       241067               4
# 35          0.002610    0.1090   0.3610  183.932       230027               4
# 36          0.000000    0.2170   0.1720  179.913       211267               4
# 37          0.000023    0.2590   0.2180   77.525       249213               4
# 38          0.000000    0.0919   0.3400  154.962       179773               4
# 39          0.000927    0.1150   0.1660  100.966       202093               4
# 40          0.000000    0.0821   0.7520  112.878       232880               4
# 41          0.000000    0.3480   0.6230  149.828       231360               4
# 42          0.000000    0.1300   0.3210  134.022       224213               4
# 43          0.000034    0.1890   0.1920  173.978       220307               4
# 44          0.000000    0.0465   0.5390  168.022       235653               3
# 45          0.000009    0.0891   0.8640  113.998       220173               4
# 46          0.000010    0.4600   0.7630  109.945       265600               4
# 47          0.000000    0.0878   0.1910  109.825       198653               4
# 48          0.000000    0.1810   0.3090   74.640       334333               4
# 49          0.000667    0.0777   0.0687   74.950       247227               4

# %%
#getting correlation matrix
f, ax = plt.subplots(figsize=(10, 8))
corr = df.corr()
sns.heatmap(corr, mask=np.zeros_like(corr, dtype=np.bool_), cmap=sns.diverging_palette(220, 10, as_cmap=True),
            square=True, ax=ax)
plt.title('Correlation Matrix of track data')
# Out:
# Text(0.5, 1.0, 'Correlation Matrix of track data')

# %%
# correlation between danceability and energy

x = df['danceability'].values
y = df['energy'].values

x = x.reshape(x.shape[0],1)
y = y.reshape(y.shape[0],1)

regr = linear_model.LinearRegression()
regr.fit(x,y)

figure = plt.figure(figsize = (6,6))
plt.title('abc')

ax = plt.subplot(1, 1, 1)
ax.scatter(x, y, alpha=0.9)
ax.plot(x, regr.predict(x), color="red", linewidth=2.5)
plt.xticks(())
plt.yticks(())

ax.xaxis.set_major_locator(ticker.MultipleLocator(0.1))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(0.02))

ax.yaxis.set_major_locator(ticker.MultipleLocator(0.1))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.02))

plt.xlabel("danceability")
plt.ylabel("valence")

plt.show()
